# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jieba
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from PIL import Image
rawimage = Image.open('cat.png').convert("L")
threshold = 0
image = rawimage.point(lambda p: 0 if p > threshold else 255)
mask = np.array(image)

# %%
import numpy as np
from PIL import Image 
mask = np.array(Image.open('dragon.jpg'));
img_colors = ImageColorGenerator(mask);

# %%
import jieba
import re
with open('dpcq.txt', encoding='utf-8') as f:
    mytext = f.read()
    mytext = re.sub(r'[\n？“”：…！，。.]', '', mytext)
    mytext = " ".join(jieba.cut(mytext))

with open('dpcq-ch.txt','w') as f:
    f.write(mytext)

# %%
with open('note.txt') as f:
    mytext = f.read()

# %%
from wordcloud import WordCloud,ImageColorGenerator

stopwords = {'的', '和', '是', '都', '而', '就',
    '都', '而', '或', '如', '以', '我',
    '你', '他', '她', '它', '们', '它们',
    '我们', '你们', '他们', '她们', '的',
    '了', '着', '有', '无', '不', '么', '在', 
     '也', '让', '吧', '这', '啊', '有些', '不过', '还', '那', '对', '道', '得'}

wordcloud = WordCloud(
    font_path='msyhl.ttc',
    mask=mask,
    background_color="white",
    stopwords=stopwords,
    repeat=True
#     contour_width=1,
#     contour_color="black",
).generate(mytext)
# wordcloud.recolor(color_func=img_colors);

# color_generator=ImageColorGenerator(image)

# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')

wordcloud.to_file('cloud.jpg')

# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = "square"

x, y = np.ogrid[:300, :300]

mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)


wc = WordCloud(background_color="white", repeat=True, mask=mask)
wc.generate(text)

plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()
